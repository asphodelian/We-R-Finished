# %%
import sqlite3
import pandas as pd

# %%
dataset = pd.read_excel("data/salary_data_states.xlsx")
dataset
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 0       I-200-14073-248840               denied          3/14/2014
# 1            A-15061-55212               denied          3/19/2015
# 2       I-200-13256-001092               denied          9/13/2013
# 3       I-200-14087-353657               denied          3/28/2014
# 4       I-203-14259-128844               denied          9/16/2014
# ...                    ...                  ...                ...
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                                      EMPLOYER_NAME  \
# 0          3/21/2014                ADVANCED TECHNOLOGY GROUP USA, INC.
# ...

# %%
#Group by Job SubType of average wage
# Group data by job type and calculate mean salary for each group
mean_salary_by_job_type = dataset.groupby('JOB_TITLE_SUBGROUP')['PAID_WAGE_PER_YEAR'].mean()

# Sort job types by mean salary in descending order
sorted_job_types = mean_salary_by_job_type.sort_values(ascending=False)

print(sorted_job_types)
# Out:
# JOB_TITLE_SUBGROUP
# attorney                 146413.596714
# management consultant    108251.334662
# data scientist           108021.038248
# assistant professor       94876.713707
# software engineer         92505.303013
# business analyst          71300.079566
# data analyst              70030.078688
# teacher                   46039.985507
# Name: PAID_WAGE_PER_YEAR, dtype: float64

# %%
#Which companies have the highest salaries for those sub types
# Group data by job type and find the company that pays the highest salary for each group
highest_salary_by_job_type = dataset.groupby('JOB_TITLE_SUBGROUP').apply(lambda x: x.loc[x['PAID_WAGE_PER_YEAR'].idxmax()])

print(highest_salary_by_job_type[['EMPLOYER_NAME', 'PAID_WAGE_PER_YEAR']])
# Out:
#                                                        EMPLOYER_NAME  \
# JOB_TITLE_SUBGROUP
# assistant professor                      DIXIE STATE COLLEGE OF UTAH
# attorney                                        WINSTON & STRAWN LLP
# business analyst       THE UNIVERSITY OF TEXAS SYSTEM ADMINISTRATION
# data analyst                                                  INTUIT
# data scientist                                         NETFLIX, INC.
# management consultant                     CO-CREATION PARTNERS, INC.
# software engineer                                 KPI PARTNERS, INC.
# teacher                                   FROSTBURG STATE UNIVERSITY
#
#                        PAID_WAGE_PER_YEAR
# JOB_TITLE_SUBGROUP
# assistant professor              895000.0
# attorney                        2500000.0
# business analyst                1250784.0
# data analyst                     746323.0
# data scientist                   230000.0
# management consultant            582400.0
# ...

# %%
#Changes with location of the job?
mean_salary_by_job_type_location = dataset.groupby('WORK_STATE')['PAID_WAGE_PER_YEAR'].mean()

# Sort locations by mean salary in descending order
sorted_locations = mean_salary_by_job_type_location.sort_values(ascending=False)

# Print the results
print(sorted_locations)
# Out:
# WORK_STATE
# West Virginia               109426.868925
# California                  103571.109230
# Washington                  102176.679145
# New York                     91601.758915
# Arkansas                     90270.748799
# Alabama                      87326.275474
# Massachusetts                86610.726739
# Pennsylvania                 83889.437310
# District of Columbia         81968.360095
# Mississippi                  81950.747813
# Oregon                       81530.546156
# Kansas                       81031.775751
# Kentucky                     80146.977145
# Connecticut                  79578.567355
# Maryland                     79153.982504
# Nevada                       79152.477377
# Indiana                      78722.992183
# Iowa                         78219.470771
# Wisconsin                    77728.956490
# New Hampshire                77434.658103
# Utah                         77240.403448
# Illinois                     77113.749393
# ...

# %%
#Will the Answer Change if we take standard of living into account?
